# %%
import pandas as pd

# %%
factors = pd.read_hdf('data.h5', 'factors/formulaic')

# %%
factors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1034424 entries, ('A', Timestamp('2010-01-05 00:00:00')) to ('ZION', Timestamp('2018-03-26 00:00:00'))
# Data columns (total 82 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   1       1022844 non-null  float64
#  1   2       1022239 non-null  float64
#  2   3       1008994 non-null  float64
#  3   4       1030102 non-null  float64
#  4   5       1026505 non-null  float64
#  5   6       1029567 non-null  float64
#  6   7       1020664 non-null  float64
#  7   8       1027030 non-null  float64
#  8   9       1025940 non-null  float64
#  9   10      1025940 non-null  float64
#  10  11      1024336 non-null  float64
#  11  12      1025940 non-null  float64
#  12  13      1022844 non-null  float64
#  13  14      1029567 non-null  float64
#  14  15      837068 non-null   float64
#  15  16      1032242 non-null  float64
#  16  17      1020124 non-null  float64
# ...

# %%
ohlcv = ['open', 'high', 'low', 'close', 'volume']
data = (pd.read_hdf('data.h5', 'data/top500')
        .loc[:, ohlcv + ['ret_01', 'ret_fwd']]
        .rename(columns={'ret_01': 'returns'})
        .sort_index())

# %%
data
# Out:
#                         open       high        low      close     volume  \
# ticker date
# A      2010-01-05  21.292732  21.299554  20.985724  21.122172  2994300.0
#        2010-01-06  21.047125  21.149461  20.985724  21.047125  2320300.0
#        2010-01-07  20.999368  21.026658  20.808341  21.019836  2214000.0
#        2010-01-08  20.903855  21.047125  20.740117  21.013013  2670900.0
#        2010-01-11  21.067592  21.183573  20.924322  21.026658  3420300.0
# ...                      ...        ...        ...        ...        ...
# ZION   2018-03-20  55.350000  55.471200  54.470000  54.800000  2643688.0
#        2018-03-21  54.940000  55.780000  54.390000  55.100000  1992966.0
#        2018-03-22  54.530000  54.700000  52.970000  53.070000  2578239.0
#        2018-03-23  53.220000  53.550000  51.170000  51.230000  3378671.0
#        2018-03-26  52.200000  53.410000  51.900000  53.240000  2357767.0
#
#                     returns   ret_fwd
# ticker date
# ...

# %%
df = pd.merge(data, factors, left_index=True, right_index=True)

# %%
df.to_feather('factor_ret_all.feather')
# Out:
# D:\anaconda3\Lib\site-packages\pyarrow\feather.py:156: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = Table.from_pandas(df, preserve_index=preserve_index)
